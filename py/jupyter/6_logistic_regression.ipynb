# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
plt.scatter(df['age'],df['bought_insurance'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[['age']],df['bought_insurance'],test_size=0.2)

reg=LinearRegression()
reg.fit(X_train,y_train)
plt.scatter(df['age'],df['bought_insurance'])
plt.plot(df['age'],reg.predict(df[['age']]),color='red')

# %%
reg.predict([[47]])
# Out:
# array([0.611044])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
plt.plot(sigmoid(np.arange(-80,80.0)))

# %%
from sklearn.linear_model import LogisticRegression
reg2=LogisticRegression()
reg2.fit(X_train,y_train)
plt.scatter(df['age'],df['bought_insurance'])
plt.plot(df['age'],reg2.predict(df[['age']]),color='red')
plt.plot(sigmoid(reg2.predict(X)))
#plt.plot(sigmoid(df["age"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-b20b97d384d6> in <module>
#       4 plt.scatter(df['age'],df['bought_insurance'])
#       5 plt.plot(df['age'],reg2.predict(df[['age']]),color='red')
# ----> 6 plt.plot(sigmoid(reg2.predict(X)))
#       7 #plt.plot(sigmoid(df["age"]))
#
# NameError: name 'X' is not defined

# %%
reg2.predict([[47]])
# Out:
# array([1])

# %%
X_test
# Out:
#     age
# 19   18
# 5    56
# 1    25
# 16   25
# 22   40
# 9    61

# %%
reg2.predict(X_test)
# Out:
# array([0, 1, 0, 0, 0, 1])

# %%
reg2.score(X_test,y_test)
# Out:
# 0.6666666666666666
