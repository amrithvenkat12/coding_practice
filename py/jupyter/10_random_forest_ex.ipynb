# %%
import pandas as pd 
df = pd.read_csv('datasets/iris.csv')
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
X=df.drop(['flower_name','target'],axis='columns')
y=df['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn

# %%
model = RandomForestClassifier(n_estimators=10)
model.fit(X_train,y_train)

y_pred = model.predict(X_test)
print(y_pred)

score=model.score(X_test,y_test)
print(score)

cn = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(5,5))
sn.heatmap(cn,annot=True)
plt.xlabel('Pred')
plt.ylabel('Truth')
# Out:
# [1 0 0 1 2 1 2 2 1 1 2 2 2 0 0 2 2 1 2 2 0 1 0 2 2 2 2 1 2 1]
# 0.9333333333333333
# Text(24.0, 0.5, 'Truth')

# %%
model1 = RandomForestClassifier(n_estimators=100)
model1.fit(X_train,y_train)

y_pred1 = model1.predict(X_test)
print(y_pred1)

score1=model1.score(X_test,y_test)
print(score1)

cn1 = confusion_matrix(y_test,y_pred)
plt.figure(figsize=(5,5))
sn.heatmap(cn1,annot=True)
plt.xlabel('Pred')
plt.ylabel('Truth')
# Out:
# [1 0 0 1 2 1 2 2 1 1 2 2 2 0 0 2 2 1 2 2 0 1 0 2 2 2 2 1 1 1]
# 0.9666666666666667
# Text(24.0, 0.5, 'Truth')
